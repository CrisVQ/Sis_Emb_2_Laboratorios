# %%
import pandas as pd

data = {
    'Nombre del estudiante': ['Ana', 'Luis', 'Carlos', 'María', 'Sofía'],
    'Edad del estudiante': [20, 22, 19, 21, 23],
    'Número de prácticas realizadas': [10, 12, 9, 14, 11],
    'Puntaje promedio': [85, 90, 78, 92, 88]
}

df = pd.DataFrame(data)

df.to_excel('estudiantes.xlsx', index=False)

# %%
import pandas as pd

df = pd.read_excel('estudiantes.xlsx')

for _, row in df.iterrows():
    print(f"Nombre: {row['Nombre del estudiante']}, Edad: {row['Edad del estudiante']}, Número de prácticas: {row['Número de prácticas realizadas']}")



print("\nInformación completa de los estudiantes:")
print(df)
# Out:
# Nombre: Ana, Edad: 20, Número de prácticas: 10
# Nombre: Luis, Edad: 22, Número de prácticas: 12
# Nombre: Carlos, Edad: 19, Número de prácticas: 9
# Nombre: María, Edad: 21, Número de prácticas: 14
# Nombre: Sofía, Edad: 23, Número de prácticas: 11
#
# Información completa de los estudiantes:
#   Nombre del estudiante  Edad del estudiante  Número de prácticas realizadas  \
# 0                   Ana                   20                              10
# 1                  Luis                   22                              12
# 2                Carlos                   19                               9
# 3                 María                   21                              14
# 4                 Sofía                   23                              11
#
#    Puntaje promedio
# 0                85
# 1                90
# 2                78
# 3                92
# 4                88
